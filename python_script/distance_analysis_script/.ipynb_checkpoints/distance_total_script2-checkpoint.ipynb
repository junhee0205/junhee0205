# %%
import pandas as pd
import numpy as np

# %%
a01 = pd.read_table("/hdd/Correlation_Disance/chr01_distance.csv", sep = ',')

# %%
a02 = pd.read_table("/hdd/Correlation_Disance/chr02_distance.csv", sep = ',')

# %%
a03 = pd.read_table("/hdd/Correlation_Disance/chr03_distance.csv", sep = ',')

# %%
a04 = pd.read_table("/hdd/Correlation_Disance/chr04_distance.csv", sep = ',')

# %%
a05 = pd.read_table("/hdd/Correlation_Disance/chr05_distance.csv", sep = ',')

# %%
a06 = pd.read_table("/hdd/Correlation_Disance/chr06_distance.csv", sep = ',')

# %%
a07 = pd.read_table("/hdd/Correlation_Disance/chr07_distance.csv", sep = ',')

# %%
a08 = pd.read_table("/hdd/Correlation_Disance/chr08_distance.csv", sep = ',')

# %%
a09 = pd.read_table("/hdd/Correlation_Disance/chr09_distance.csv", sep = ',')

# %%
a10 = pd.read_table("/hdd/Correlation_Disance/chr10_distance.csv", sep = ',')

# %%
a11 = pd.read_table("/hdd/Correlation_Disance/chr11_distance.csv", sep = ',')

# %%
a12 = pd.read_table("/hdd/Correlation_Disance/chr12_distance.csv", sep = ',')

# %%
a13 = pd.read_table("/hdd/Correlation_Disance/chr13_distance.csv", sep = ',')

# %%
a14 = pd.read_table("/hdd/Correlation_Disance/chr14_distance.csv", sep = ',')

# %%
a15 = pd.read_table("/hdd/Correlation_Disance/chr15_distance.csv", sep = ',')

# %%
a16 = pd.read_table("/hdd/Correlation_Disance/chr16_distance.csv", sep = ',')

# %%
a17 = pd.read_table("/hdd/Correlation_Disance/chr17_distance.csv", sep = ',')

# %%
a18 = pd.read_table("/hdd/Correlation_Disance/chr18_distance.csv", sep = ',')

# %%
a19 = pd.read_table("/hdd/Correlation_Disance/chr19_distance.csv", sep = ',')

# %%
a20 = pd.read_table("/hdd/Correlation_Disance/chr20_distance.csv", sep = ',')

# %%
a21 = pd.read_table("/hdd/Correlation_Disance/chr21_distance.csv", sep = ',')

# %%
a22 = pd.read_table("/hdd/Correlation_Disance/chr22_distance.csv", sep = ',')

# %%
a23 = pd.read_table("/hdd/Correlation_Disance/chr23_distance.csv", sep = ',')

# %%
a24 = pd.read_table("/hdd/Correlation_Disance/chr24_distance.csv", sep = ',')

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b01 = a01[cols]
b01.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a01 = a01.append(b01)
a01 = a01.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b02 = a02[cols]
b02.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a02 = a02.append(b01)
a02 = a02.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b03 = a03[cols]
b03.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a03 = a03.append(b01)
a03 = a03.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b04 = a04[cols]
b04.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a04 = a04.append(b01)
a04 = a04.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b05 = a05[cols]
b05.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a05 = a05.append(b01)
a05 = a05.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b06 = a06[cols]
b06.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a06 = a06.append(b01)
a06 = a06.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b07 = a07[cols]
b07.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a07 = a07.append(b01)
a07 = a07.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b08 = a08[cols]
b08.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a08 = a08.append(b01)
a08 = a08.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b09 = a09[cols]
b09.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a09 = a09.append(b01)
a09 = a09.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b10 = a10[cols]
b10.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a10 = a10.append(b01)
a10 = a10.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b11 = a11[cols]
b11.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a11 = a11.append(b01)
a11 = a11.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b12 = a12[cols]
b12.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a12 = a12.append(b01)
a12 = a12.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b13 = a13[cols]
b13.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a13 = a13.append(b01)
a13 = a13.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b14 = a14[cols]
b14.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a14 = a14.append(b01)
a14 = a14.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b15 = a15[cols]
b15.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a15 = a15.append(b01)
a15 = a15.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b16 = a16[cols]
b16.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a16 = a16.append(b01)
a16 = a16.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b17 = a17[cols]
b17.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a17 = a17.append(b01)
a17 = a17.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b18 = a18[cols]
b18.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a18 = a18.append(b01)
a18 = a18.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b19 = a19[cols]
b19.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a19 = a19.append(b01)
a19 = a19.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b20 = a20[cols]
b20.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a20 = a20.append(b01)
a20 = a20.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b21 = a21[cols]
b21.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a21 = a21.append(b01)
a21 = a21.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b22 = a22[cols]
b22.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a22 = a22.append(b01)
a22 = a22.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b23 = a23[cols]
b23.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a23 = a23.append(b01)
a23 = a23.drop_duplicates()

# %%
cols = ['Unnamed: 0', 'to', 'from', 'distance']
b24 = a24[cols]
b24.columns = ['Unnamed: 0', 'from', 'to', 'distance']
a24 = a24.append(b01)
a24 = a24.drop_duplicates()

# %%
a01.to_csv('/hdd/Correlation_Disance/distance_renew/chr01_distance_renew.csv', sep = ',', header = True)

# %%
a02.to_csv('/hdd/Correlation_Disance/distance_renew/chr02_distance_renew.csv', sep = ',', header = True)

# %%
a03.to_csv('/hdd/Correlation_Disance/distance_renew/chr03_distance_renew.csv', sep = ',', header = True)

# %%
a04.to_csv('/hdd/Correlation_Disance/distance_renew/chr04_distance_renew.csv', sep = ',', header = True)

# %%
a05.to_csv('/hdd/Correlation_Disance/distance_renew/chr05_distance_renew.csv', sep = ',', header = True)

# %%
a06.to_csv('/hdd/Correlation_Disance/distance_renew/chr06_distance_renew.csv', sep = ',', header = True)

# %%
a07.to_csv('/hdd/Correlation_Disance/distance_renew/chr07_distance_renew.csv', sep = ',', header = True)

# %%
a08.to_csv('/hdd/Correlation_Disance/distance_renew/chr08_distance_renew.csv', sep = ',', header = True)

# %%
a09.to_csv('/hdd/Correlation_Disance/distance_renew/chr09_distance_renew.csv', sep = ',', header = True)

# %%
a10.to_csv('/hdd/Correlation_Disance/distance_renew/chr10_distance_renew.csv', sep = ',', header = True)

# %%
a11.to_csv('/hdd/Correlation_Disance/distance_renew/chr11_distance_renew.csv', sep = ',', header = True)

# %%
a12.to_csv('/hdd/Correlation_Disance/distance_renew/chr12_distance_renew.csv', sep = ',', header = True)

# %%
a13.to_csv('/hdd/Correlation_Disance/distance_renew/chr13_distance_renew.csv', sep = ',', header = True)

# %%
a14.to_csv('/hdd/Correlation_Disance/distance_renew/chr14_distance_renew.csv', sep = ',', header = True)

# %%
a15.to_csv('/hdd/Correlation_Disance/distance_renew/chr15_distance_renew.csv', sep = ',', header = True)

# %%
a16.to_csv('/hdd/Correlation_Disance/distance_renew/chr16_distance_renew.csv', sep = ',', header = True)

# %%
a17.to_csv('/hdd/Correlation_Disance/distance_renew/chr17_distance_renew.csv', sep = ',', header = True)

# %%
a18.to_csv('/hdd/Correlation_Disance/distance_renew/chr18_distance_renew.csv', sep = ',', header = True)

# %%
a19.to_csv('/hdd/Correlation_Disance/distance_renew/chr19_distance_renew.csv', sep = ',', header = True)

# %%
a20.to_csv('/hdd/Correlation_Disance/distance_renew/chr20_distance_renew.csv', sep = ',', header = True)

# %%
a21.to_csv('/hdd/Correlation_Disance/distance_renew/chr21_distance_renew.csv', sep = ',', header = True)

# %%
a22.to_csv('/hdd/Correlation_Disance/distance_renew/chr22_distance_renew.csv', sep = ',', header = True)

# %%
a23.to_csv('/hdd/Correlation_Disance/distance_renew/chr23_distance_renew.csv', sep = ',', header = True)

# %%
a24.to_csv('/hdd/Correlation_Disance/distance_renew/chr24_distance_renew.csv', sep = ',', header = True)
