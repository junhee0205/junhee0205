# %%
import numpy as np
import pandas as pd
import csv

# %%
a = pd.read_csv('/hdd/Correlation_Disance/chr2_distance_01.csv', sep=',')

# %%
b = pd.read_csv('/hdd/Correlation_Disance/chr2_distance_02.csv', sep=',')

# %%
c = pd.read_csv('/hdd/Correlation_Disance/chr2_distance_03.csv', sep=',')

# %%
d = pd.read_csv('/hdd/Correlation_Disance/chr2_distance_04.csv', sep=',')

# %%
e = a.append(b).append(c).append(d)

# %%
e.head()
# Out:
#            from            to  distance
# 0  LOC105373324  LOC105373324  -28260.0
# 1  LOC105373324        SH3YL1   27591.0
# 2  LOC105373324       FAM150B   89013.0
# 3  LOC105373324  LOC105373346  100399.0
# 4  LOC105373324     LOC727944  299495.0

# %%
e.to_csv('/hdd/Correlation_Disance/chr2_distance.csv', header = True, index = False)
