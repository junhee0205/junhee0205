# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
a = pd.read_table('/hdd/Correlation_Disance/gene_location_data/order_chr07-.txt', delim_whitespace=True, header = 'infer')

# %%
b = pd.read_table('/hdd/Correlation_Disance/gene_location_data/order_chr07+.txt', delim_whitespace=True, header = 'infer')

# %%
a['max'] = a[['ExonStart', 'ExonEnd']].apply(max, axis=1)
b['max'] = b[['ExonStart', 'ExonEnd']].apply(max, axis=1)

a['min'] = a[['ExonStart', 'ExonEnd']].apply(min, axis=1)
b['min'] = b[['ExonStart', 'ExonEnd']].apply(min, axis=1)

a['mean'] = a[['ExonEnd', 'ExonStart']].mean(axis=1)
b['mean'] = b[['ExonEnd', 'ExonStart']].mean(axis=1)
b[['diff']] = b[['max']].sub(b['min'], axis = 0).div(2)
a[['diff']] = a[['max']].sub(a['min'], axis = 0).div(2)

# %%
import pandas as pd
import numpy as np
from IPython.display import clear_output

# %%
a.count()
# Out:
# name2        897
# ExonStart    897
# ExonEnd      897
# max          897
# min          897
# mean         897
# diff         897
# dtype: int64

# %%
b.count()
# Out:
# name2        976
# ExonEnd      976
# ExonStart    976
# max          976
# min          976
# mean         976
# diff         976
# dtype: int64

# %%
sense = pd.DataFrame()
for i in range(1, 897):
    clear_output()
    for k in range(i+1, 976):
        t1 = b.iloc[i]
        t2 = b.iloc[k]
        flag = 'sense'
        t3 = pd.DataFrame([[t1.name2, t2.name2, abs(t2['mean'] - t1['mean']) - (t1['diff'] + t2['diff']), flag]], columns=('from','to', 'distance', 'flag'))
        sense = sense.append(t3)
        print(i, '/', '897', '|', k, '/', '976')
# Out:
# 7 / 897 | 8 / 976
# 7 / 897 | 9 / 976
# 7 / 897 | 10 / 976
# 7 / 897 | 11 / 976
# 7 / 897 | 12 / 976
# 7 / 897 | 13 / 976
# 7 / 897 | 14 / 976
# 7 / 897 | 15 / 976
# 7 / 897 | 16 / 976
# 7 / 897 | 17 / 976
# 7 / 897 | 18 / 976
# 7 / 897 | 19 / 976
# 7 / 897 | 20 / 976
# 7 / 897 | 21 / 976
# 7 / 897 | 22 / 976
# 7 / 897 | 23 / 976
# 7 / 897 | 24 / 976
# 7 / 897 | 25 / 976
# 7 / 897 | 26 / 976
# 7 / 897 | 27 / 976
# 7 / 897 | 28 / 976
# 7 / 897 | 29 / 976
# 7 / 897 | 30 / 976
# 7 / 897 | 31 / 976
# 7 / 897 | 32 / 976
# 7 / 897 | 33 / 976
# 7 / 897 | 34 / 976
# 7 / 897 | 35 / 976
# 7 / 897 | 36 / 976
# 7 / 897 | 37 / 976
# 7 / 897 | 38 / 976
# 7 / 897 | 39 / 976
# 7 / 897 | 40 / 976
# 7 / 897 | 41 / 976
# 7 / 897 | 42 / 976
# 7 / 897 | 43 / 976
# 7 / 897 | 44 / 976
# 7 / 897 | 45 / 976
# 7 / 897 | 46 / 976
# 7 / 897 | 47 / 976
# 7 / 897 | 48 / 976
# 7 / 897 | 49 / 976
# 7 / 897 | 50 / 976
# 7 / 897 | 51 / 976
# 7 / 897 | 52 / 976
# 7 / 897 | 53 / 976
# 7 / 897 | 54 / 976
# 7 / 897 | 55 / 976
# 7 / 897 | 56 / 976
# 7 / 897 | 57 / 976
# 7 / 897 | 58 / 976
# 7 / 897 | 59 / 976
# 7 / 897 | 60 / 976
# 7 / 897 | 61 / 976
# 7 / 897 | 62 / 976
# 7 / 897 | 63 / 976
# 7 / 897 | 64 / 976
# 7 / 897 | 65 / 976
# 7 / 897 | 66 / 976
# 7 / 897 | 67 / 976
# 7 / 897 | 68 / 976
# 7 / 897 | 69 / 976
# 7 / 897 | 70 / 976
# 7 / 897 | 71 / 976
# 7 / 897 | 72 / 976
# 7 / 897 | 73 / 976
# 7 / 897 | 74 / 976
# 7 / 897 | 75 / 976
# 7 / 897 | 76 / 976
# 7 / 897 | 77 / 976
# 7 / 897 | 78 / 976
# 7 / 897 | 79 / 976
# 7 / 897 | 80 / 976
# 7 / 897 | 81 / 976
# 7 / 897 | 82 / 976
# 7 / 897 | 83 / 976
# 7 / 897 | 84 / 976
# 7 / 897 | 85 / 976
# 7 / 897 | 86 / 976
# 7 / 897 | 87 / 976
# 7 / 897 | 88 / 976
# 7 / 897 | 89 / 976
# 7 / 897 | 90 / 976
# 7 / 897 | 91 / 976
# 7 / 897 | 92 / 976
# 7 / 897 | 93 / 976
# 7 / 897 | 94 / 976
# 7 / 897 | 95 / 976
# 7 / 897 | 96 / 976
# 7 / 897 | 97 / 976
# 7 / 897 | 98 / 976
# 7 / 897 | 99 / 976
# 7 / 897 | 100 / 976
# 7 / 897 | 101 / 976
# 7 / 897 | 102 / 976
# 7 / 897 | 103 / 976
# 7 / 897 | 104 / 976
# 7 / 897 | 105 / 976
# 7 / 897 | 106 / 976
# 7 / 897 | 107 / 976
# 7 / 897 | 108 / 976
# 7 / 897 | 109 / 976
# 7 / 897 | 110 / 976
# 7 / 897 | 111 / 976
# 7 / 897 | 112 / 976
# 7 / 897 | 113 / 976
# 7 / 897 | 114 / 976
# 7 / 897 | 115 / 976
# 7 / 897 | 116 / 976
# 7 / 897 | 117 / 976
# 7 / 897 | 118 / 976
# 7 / 897 | 119 / 976
# 7 / 897 | 120 / 976
# 7 / 897 | 121 / 976

# %%
antisense.head()
# Out:
#       from            to  distance       flag
# 0  FAM138A  LOC100996442   55087.0  antisense
# 0  FAM138A     LOC729737   98691.0  antisense
# 0  FAM138A  LOC102723897  148796.0  antisense
# 0  FAM138A     MIR6859-2  151809.0  antisense
# 0  FAM138A        OR4F29  414658.0  antisense

# %%
sense.to_csv('/hdd/Correlation_Disance/chr01_sense_01.csv')
