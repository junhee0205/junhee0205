# %%
import numpy as np
import pandas as pd
import csv

# %%
a = pd.read_csv('/hdd/Correlation_Disance/chr07_distance_flag_01.csv')

# %%
b = pd.read_csv('/hdd/Correlation_Disance/chr07_distance_flag_02.csv')

# %%
c = pd.read_csv('/hdd/Correlation_Disance/chr07_distance_flag_03.csv')

# %%
e = a.append(b).append(c)

# %%
e.head()
# Out:
#            from            to  distance flag
# 0  LOC105375112  LOC101929756   39098.0   TT
# 1  LOC105375112  LOC100507642  111778.0   TT
# 2  LOC105375112  LOC105375115  136980.0   TT
# 3  LOC105375112  LOC105375116  138257.0   TT
# 4  LOC105375112        FAM20C  154999.0   TT

# %%
e = e.drop(['Unnamed: 0'], axis = 1)

# %%
e.to_csv('/hdd/Correlation_Disance/chr07_distance_flag.csv', header = True, index = False)
